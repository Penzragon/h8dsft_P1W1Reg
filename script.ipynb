# %% [markdown]
# # Hacktiv8 Phase 1: Graded Challenge 1
#
# ---
#
# Graded Challenge ini dibuat guna mengevaluasi pembelajaran pada Hacktiv8 Data Science Fulltime Program khususnya pada konsep Regression.

# %% [markdown]
# ## Introduction

# %% [markdown]
# By [Rifky Aliffa](https://github.com/Penzragon)
#
# ![Uber vs Lyft](https://photos5.appleinsider.com/gallery/37267-69909-1OLXiBSIR4zfrwXBI_emrgQ-xl.jpg)

# %% [markdown]
# ### Dataset
#
# Dataset yang digunakan pada project ini adalah dataset yang berisi tentang data perjalanan penumpang menggunakan **Uber** dan **Lyft** yang sudah termasuk informasi cuaca pada jam tersebut. Dataset ini berisi 693071 baris dengan 57 kolom yang di antaranya adalah id, timestamp, hour, day, month, datetime, timezone, source, destination, cab_type, product_id, name, price, distance, dan masih banyak lagi. Dataset dapat dilihat di [Kaggle](https://www.kaggle.com/brllrb/uber-and-lyft-dataset-boston-ma).

# %% [markdown]
# ### Objectives
#
# **Graded Challenge 1** ini dibuat guna mengevaluasi konsep Regression sebagai berikut:
#
# - Mampu memahami konsep regression dengan Linear Regession
# - Mampu mempersiapkan data untuk digunakan dalam model Linear Regression
# - Mampu mengimplementasikan Linear Regression untuk membuat prediksi

# %% [markdown]
# ## Import Libraries

# %% [markdown]
# Pada project kali ini library yang akan digunakan adalah **Pandas**, **Numpy**, **Matplotlib**, **Seaborn**, dan **Scikit-Learn**.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# Melakukan setting agar pandas menampilkan seluruh kolom pada dataframe.

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Data Loading

# %% [markdown]
# membuat dataframe dari file `rideshare_kaggle.csv`.

# %%
rides = pd.read_csv('rideshare_kaggle.csv')

# %%
rides.head()
# Out:
#                                      id     timestamp  hour  day  month  \
# 0  424553bb-7174-41ea-aeb4-fe06d4f4b9d7  1.544953e+09     9   16     12
# 1  4bd23055-6827-41c6-b23b-3c491f24e74d  1.543284e+09     2   27     11
# 2  981a3613-77af-4620-a42a-0c0866077d1e  1.543367e+09     1   28     11
# 3  c2d88af2-d278-4bfd-a8d0-29ca77cc5512  1.543554e+09     4   30     11
# 4  e0126e1f-8ca9-4f2e-82b3-50505a09db9a  1.543463e+09     3   29     11
#
#               datetime          timezone            source    destination  \
# 0  2018-12-16 09:30:07  America/New_York  Haymarket Square  North Station
# 1  2018-11-27 02:00:23  America/New_York  Haymarket Square  North Station
# 2  2018-11-28 01:00:22  America/New_York  Haymarket Square  North Station
# 3  2018-11-30 04:53:02  America/New_York  Haymarket Square  North Station
# 4  2018-11-29 03:49:20  America/New_York  Haymarket Square  North Station
#
#   cab_type    product_id          name  price  distance  surge_multiplier  \
# 0     Lyft     lyft_line        Shared    5.0      0.44               1.0
# 1     Lyft  lyft_premier           Lux   11.0      0.44               1.0
# 2     Lyft          lyft          Lyft    7.0      0.44               1.0
# 3     Lyft   lyft_luxsuv  Lux Black XL   26.0      0.44               1.0
# 4     Lyft     lyft_plus       Lyft XL    9.0      0.44               1.0
#
#    latitude  longitude  temperature  apparentTemperature    short_summary  \
# 0   42.2148    -71.033        42.34                37.12   Mostly Cloudy
# 1   42.2148    -71.033        43.58                37.35            Rain
# 2   42.2148    -71.033        38.33                32.93           Clear
# 3   42.2148    -71.033        34.38                29.63           Clear
# 4   42.2148    -71.033        37.44                30.88   Partly Cloudy
#
#                                         long_summary  precipIntensity  \
# 0                          Rain throughout the day.            0.0000
# 1   Rain until morning, starting again in the eve...           0.1299
# 2                        Light rain in the morning.            0.0000
# 3                 Partly cloudy throughout the day.            0.0000
# 4                 Mostly cloudy throughout the day.            0.0000
#
#    precipProbability  humidity  windSpeed  windGust  windGustTime  visibility  \
# 0                0.0      0.68       8.66      9.17    1545015600      10.000
# 1                1.0      0.94      11.98     11.98    1543291200       4.786
# 2                0.0      0.75       7.33      7.33    1543334400      10.000
# 3                0.0      0.73       5.28      5.28    1543514400      10.000
# 4                0.0      0.70       9.14      9.14    1543446000      10.000
#
#    temperatureHigh  temperatureHighTime  temperatureLow  temperatureLowTime  \
# 0            43.68           1544968800           34.19          1545048000
# 1            47.30           1543251600           42.10          1543298400
# 2            47.55           1543320000           33.10          1543402800
# 3            45.03           1543510800           28.90          1543579200
# 4            42.18           1543420800           36.71          1543478400
#
#    apparentTemperatureHigh  apparentTemperatureHighTime  \
# 0                    37.95                   1544968800
# 1                    43.92                   1543251600
# 2                    44.12                   1543320000
# 3                    38.53                   1543510800
# 4                    35.75                   1543420800
#
#    apparentTemperatureLow  apparentTemperatureLowTime                   icon  \
# 0                   27.39                  1545044400   partly-cloudy-night
# 1                   36.20                  1543291200                  rain
# 2                   29.11                  1543392000           clear-night
# 3                   26.20                  1543575600           clear-night
# 4                   30.29                  1543460400   partly-cloudy-night
#
#    dewPoint  pressure  windBearing  cloudCover  uvIndex  visibility.1  ozone  \
# 0     32.70   1021.98           57        0.72        0        10.000  303.8
# 1     41.83   1003.97           90        1.00        0         4.786  291.1
# 2     31.10    992.28          240        0.03        0        10.000  315.7
# 3     26.64   1013.73          310        0.00        0        10.000  291.1
# 4     28.61    998.36          303        0.44        0        10.000  347.7
#
#    sunriseTime  sunsetTime  moonPhase  precipIntensityMax  uvIndexTime  \
# 0   1544962084  1544994864       0.30              0.1276   1544979600
# 1   1543232969  1543266992       0.64              0.1300   1543251600
# 2   1543319437  1543353364       0.68              0.1064   1543338000
# 3   1543492370  1543526114       0.75              0.0000   1543507200
# 4   1543405904  1543439738       0.72              0.0001   1543420800
#
#    temperatureMin  temperatureMinTime  temperatureMax  temperatureMaxTime  \
# 0           39.89          1545012000           43.68          1544968800
# 1           40.49          1543233600           47.30          1543251600
# 2           35.36          1543377600           47.55          1543320000
# 3           34.67          1543550400           45.03          1543510800
# 4           33.10          1543402800           42.18          1543420800
#
#    apparentTemperatureMin  apparentTemperatureMinTime  apparentTemperatureMax  \
# 0                   33.73                  1545012000                   38.07
# 1                   36.20                  1543291200                   43.92
# 2                   31.04                  1543377600                   44.12
# 3                   30.30                  1543550400                   38.53
# 4                   29.11                  1543392000                   35.75
#
#    apparentTemperatureMaxTime
# 0                  1544958000
# 1                  1543251600
# 2                  1543320000
# 3                  1543510800
# 4                  1543420800

# %% [markdown]
# ### Data Characteristics

# %%
rides.shape
# Out:
# (693071, 57)

# %% [markdown]
# Dataframe ini terbentuk dari:
# - **693071** baris
# - **57** kolom

# %%
rides.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 693071 entries, 0 to 693070
# Data columns (total 57 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           693071 non-null  object
#  1   timestamp                    693071 non-null  float64
#  2   hour                         693071 non-null  int64
#  3   day                          693071 non-null  int64
#  4   month                        693071 non-null  int64
#  5   datetime                     693071 non-null  object
#  6   timezone                     693071 non-null  object
#  7   source                       693071 non-null  object
#  8   destination                  693071 non-null  object
#  9   cab_type                     693071 non-null  object
#  10  product_id                   693071 non-null  object
#  11  name                         693071 non-null  object
#  12  price                        637976 non-null  float64
#  13  distance                     693071 non-null  float64
#  14  surge_multiplier             693071 non-null  float64
#  15  latitude                     693071 non-null  float64
#  16  longitude                    693071 non-null  float64
#  17  temperature                  693071 non-null  float64
#  18  apparentTemperature          693071 non-null  float64
#  19  short_summary                693071 non-null  object
#  20  long_summary                 693071 non-null  object
#  21  precipIntensity              693071 non-null  float64
#  22  precipProbability            693071 non-null  float64
#  23  humidity                     693071 non-null  float64
#  24  windSpeed                    693071 non-null  float64
#  25  windGust                     693071 non-null  float64
#  26  windGustTime                 693071 non-null  int64
#  27  visibility                   693071 non-null  float64
#  28  temperatureHigh              693071 non-null  float64
#  29  temperatureHighTime          693071 non-null  int64
#  30  temperatureLow               693071 non-null  float64
#  31  temperatureLowTime           693071 non-null  int64
#  32  apparentTemperatureHigh      693071 non-null  float64
#  33  apparentTemperatureHighTime  693071 non-null  int64
#  34  apparentTemperatureLow       693071 non-null  float64
#  35  apparentTemperatureLowTime   693071 non-null  int64
#  36  icon                         693071 non-null  object
#  37  dewPoint                     693071 non-null  float64
#  38  pressure                     693071 non-null  float64
#  39  windBearing                  693071 non-null  int64
#  40  cloudCover                   693071 non-null  float64
#  41  uvIndex                      693071 non-null  int64
#  42  visibility.1                 693071 non-null  float64
#  43  ozone                        693071 non-null  float64
#  44  sunriseTime                  693071 non-null  int64
#  45  sunsetTime                   693071 non-null  int64
#  46  moonPhase                    693071 non-null  float64
#  47  precipIntensityMax           693071 non-null  float64
#  48  uvIndexTime                  693071 non-null  int64
#  49  temperatureMin               693071 non-null  float64
#  50  temperatureMinTime           693071 non-null  int64
#  51  temperatureMax               693071 non-null  float64
#  52  temperatureMaxTime           693071 non-null  int64
#  53  apparentTemperatureMin       693071 non-null  float64
#  54  apparentTemperatureMinTime   693071 non-null  int64
#  55  apparentTemperatureMax       693071 non-null  float64
#  56  apparentTemperatureMaxTime   693071 non-null  int64
# dtypes: float64(29), int64(17), object(11)
# memory usage: 301.4+ MB

# %% [markdown]
# Dari basic info ini dapat diketahui dataframe ini terdiri dari:
# - 29 kolom dengan tipe float
# - 17 kolom dengan tipe integer
# - 11 kolom dengan tipe object
#
# Dapat diketahui juga terdapat **missing value** pada kolom `price`.

# %%
rides.describe().T
# Out:
#                                 count          mean            std  \
# timestamp                    693071.0  1.544046e+09  689192.492586
# hour                         693071.0  1.161914e+01       6.948114
# day                          693071.0  1.779436e+01       9.982286
# month                        693071.0  1.158668e+01       0.492429
# price                        637976.0  1.654513e+01       9.324359
# distance                     693071.0  2.189430e+00       1.138937
# surge_multiplier             693071.0  1.013870e+00       0.091641
# latitude                     693071.0  4.233817e+01       0.047840
# longitude                    693071.0 -7.106615e+01       0.020302
# temperature                  693071.0  3.958439e+01       6.726084
# apparentTemperature          693071.0  3.588122e+01       7.918707
# precipIntensity              693071.0  8.922153e-03       0.026901
# precipProbability            693071.0  1.460758e-01       0.328938
# humidity                     693071.0  7.411187e-01       0.138595
# apparentTemperatureLowTime   1.544836e+09  1.545199e+09
# dewPoint                     3.812000e+01  5.067000e+01
# pressure                     1.021860e+03  1.035550e+03
# windBearing                  3.030000e+02  3.560000e+02
# cloudCover                   1.000000e+00  1.000000e+00
# uvIndex                      0.000000e+00  2.000000e+00
# visibility.1                 9.996000e+00  1.000000e+01
# ozone                        3.318000e+02  3.789000e+02
# sunriseTime                  1.544789e+09  1.545135e+09
# sunsetTime                   1.544822e+09  1.545168e+09
# moonPhase                    7.900000e-01  9.300000e-01
# precipIntensityMax           9.160000e-02  1.459000e-01
# uvIndexTime                  1.544807e+09  1.545152e+09
# temperatureMin               3.888000e+01  4.310000e+01
# temperatureMinTime           1.544789e+09  1.545192e+09
# temperatureMax               4.691000e+01  5.787000e+01
# temperatureMaxTime           1.544814e+09  1.545109e+09
# apparentTemperatureMin       3.571000e+01  4.005000e+01
# apparentTemperatureMinTime   1.544789e+09  1.545134e+09
# apparentTemperatureMax       4.412000e+01  5.720000e+01
# apparentTemperatureMaxTime   1.544818e+09  1.545109e+09

# %% [markdown]
# Distribusi dari kolom pada dataset kebanyakan memiliki distribusi yang cenderung normal (**Symmetrical Distribution**) contohnya pada kolom `hour`, `distance`, dan `temperature` dimana mean dari kolom tersebut berdekatan dengan mediannya.

# %% [markdown]
# ## Data Cleansing

# %% [markdown]
# ### Missing Value

# %% [markdown]
# Pada bagian ini akan dilakukan pengecekan apakah ada missing value pada setiap kolom dataframe.

# %%
rides.isna().sum()
# Out:
# id                                 0
# timestamp                          0
# hour                               0
# day                                0
# month                              0
# datetime                           0
# timezone                           0
# source                             0
# destination                        0
# cab_type                           0
# product_id                         0
# name                               0
# price                          55095
# distance                           0
# surge_multiplier                   0
# latitude                           0
# longitude                          0
# temperature                        0
# apparentTemperature                0
# short_summary                      0
# long_summary                       0
# precipIntensity                    0
# precipProbability                  0
# humidity                           0
# windSpeed                          0
# windGust                           0
# windGustTime                       0
# visibility                         0
# temperatureHigh                    0
# temperatureHighTime                0
# temperatureLow                     0
# temperatureLowTime                 0
# apparentTemperatureHigh            0
# apparentTemperatureHighTime        0
# apparentTemperatureLow             0
# apparentTemperatureLowTime         0
# icon                               0
# dewPoint                           0
# pressure                           0
# windBearing                        0
# cloudCover                         0
# uvIndex                            0
# visibility.1                       0
# ozone                              0
# sunriseTime                        0
# sunsetTime                         0
# moonPhase                          0
# precipIntensityMax                 0
# uvIndexTime                        0
# temperatureMin                     0
# temperatureMinTime                 0
# temperatureMax                     0
# temperatureMaxTime                 0
# apparentTemperatureMin             0
# apparentTemperatureMinTime         0
# apparentTemperatureMax             0
# apparentTemperatureMaxTime         0
# dtype: int64

# %%
print(f'Percentage of missing values in price column: {(rides.price.isna().sum()/len(rides)*100):.2f}%')
# Out:
# Percentage of missing values in price column: 7.95%

# %% [markdown]
# Terdapat **55095** missing value pada kolom `price` dan persentase dari missing value pada kolom ini sebesar **7.95%**.

# %%
rides[rides.price.isna()].head()
# Out:
#                                       id     timestamp  hour  day  month  \
# 18  fa5fb705-03a0-4eb9-82d9-7fe80872f754  1.543674e+09    14    1     12
# 31  eee70d94-6706-4b95-a8ce-0e34f0fa8f37  1.543795e+09    23    2     12
# 40  7f47ff53-7cf2-4a6a-8049-83c90e042593  1.543524e+09    20   29     11
# 60  43abdbe4-ab9e-4f39-afdc-31cfa375dc25  1.544732e+09    20   13     12
# 69  80db1c49-9d51-4575-a4f4-1ec23b4d3e31  1.543583e+09    13   30     11
#
#                datetime          timezone         source    destination  \
# 18  2018-12-01 14:13:04  America/New_York      North End       West End
# 31  2018-12-02 23:52:56  America/New_York    Beacon Hill  South Station
# 40  2018-11-29 20:38:05  America/New_York  North Station         Fenway
# 60  2018-12-13 20:10:16  America/New_York      North End       West End
# 69  2018-11-30 13:08:03  America/New_York      North End    Beacon Hill
#
#    cab_type                            product_id  name  price  distance  \
# 18     Uber  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a  Taxi    NaN      1.11
# 31     Uber  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a  Taxi    NaN      2.48
# 40     Uber  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a  Taxi    NaN      2.94
# 60     Uber  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a  Taxi    NaN      1.16
# 69     Uber  8cf7e821-f0d3-49c6-8eba-e679c0ebcf6a  Taxi    NaN      2.67
#
#     surge_multiplier  latitude  longitude  temperature  apparentTemperature  \
# 18               1.0   42.3647   -71.0542        36.99                32.27
# 31               1.0   42.3588   -71.0707        48.83                48.83
# 40               1.0   42.3661   -71.0631        42.50                36.47
# 60               1.0   42.3647   -71.0542        33.15                30.60
# 69               1.0   42.3647   -71.0542        31.80                31.80
#
#       short_summary                                long_summary  \
# 18   Partly Cloudy    Light rain in the morning and overnight.
# 31        Overcast                   Light rain until evening.
# 40   Partly Cloudy           Partly cloudy throughout the day.
# 60   Mostly Cloudy           Partly cloudy throughout the day.
# 69           Clear           Mostly cloudy throughout the day.
#
#     precipIntensity  precipProbability  humidity  windSpeed  windGust  \
# 18              0.0                0.0      0.68       5.87      6.26
# 31              0.0                0.0      0.96       2.83      2.98
# 40              0.0                0.0      0.54      10.68     17.15
# 60              0.0                0.0      0.57       3.02      3.02
# 69              0.0                0.0      0.83       2.10      4.79
#
#     windGustTime  visibility  temperatureHigh  temperatureHighTime  \
# 18    1543672800       9.910            44.66           1543690800
# 31    1543755600       7.790            50.73           1543788000
# 40    1543514400       9.772            44.66           1543510800
# 60    1544738400       9.956            33.83           1544731200
# 69    1543554000      10.000            42.52           1543600800
#
#     temperatureLow  temperatureLowTime  apparentTemperatureHigh  \
# 18           35.04          1543712400                    43.99
# 31           44.99          1543816800                    50.06
# 40           28.68          1543575600                    38.30
# 60           27.27          1544781600                    32.85
# 69           31.71          1543658400                    40.53
#
#     apparentTemperatureHighTime  apparentTemperatureLow  \
# 18                   1543690800                   35.69
# 31                   1543788000                   45.64
# 40                   1543510800                   27.26
# 60                   1544734800                   24.61
# 69                   1543611600                   28.06
#
#     apparentTemperatureLowTime                 icon  dewPoint  pressure  \
# 18                  1543712400   partly-cloudy-day      27.53   1022.32
# 31                  1543816800              cloudy      47.81   1002.81
# 40                  1543568400   partly-cloudy-day      26.84   1008.44
# 60                  1544785200   partly-cloudy-day      19.51   1033.96
# 69                  1543658400           clear-day      27.14   1017.01
#
#     windBearing  cloudCover  uvIndex  visibility.1  ozone  sunriseTime  \
# 18          344        0.44        1         9.910  280.1   1543665331
# 31          275        1.00        0         7.790  287.3   1543751797
# 40          314        0.35        0         9.772  307.4   1543492404
# 60           96        0.81        0         9.956  330.1   1544702792
# 69          296        0.01        0        10.000  277.1   1543578867
#
#     sunsetTime  moonPhase  precipIntensityMax  uvIndexTime  temperatureMin  \
# 18  1543698851       0.82              0.0000   1543683600           31.71
# 31  1543785238       0.86              0.0904   1543770000           36.45
# 40  1543526094       0.75              0.0000   1543510800           35.15
# 60  1544735599       0.21              0.0001   1544716800           18.29
# 69  1543612470       0.79              0.0003   1543593600           28.79
#
#     temperatureMinTime  temperatureMax  temperatureMaxTime  \
# 18          1543658400           44.66          1543690800
# 31          1543726800           50.73          1543788000
# 40          1543550400           44.66          1543510800
# 60          1544688000           33.83          1544731200
# 69          1543579200           42.52          1543600800
#
#     apparentTemperatureMin  apparentTemperatureMinTime  \
# 18                   28.06                  1543658400
# 31                   35.85                  1543748400
# 40                   30.98                  1543550400
# 60                   13.79                  1544688000
# 69                   26.41                  1543575600
#
#     apparentTemperatureMax  apparentTemperatureMaxTime
# 18                   43.99                  1543690800
# 31                   50.06                  1543788000
# 40                   38.30                  1543510800
# 60                   32.85                  1544734800
# 69                   40.53                  1543611600

# %%
rides[rides.price.isna()].name.value_counts()
# Out:
# Taxi    55095
# Name: name, dtype: int64

# %%
rides[rides.price.isna()].cab_type.value_counts()
# Out:
# Uber    55095
# Name: cab_type, dtype: int64

# %% [markdown]
# Pada dataset seluruh data yang memiliki **missing value** pada kolom `price` adalah data dari penumpang yang menggunakan **Taxi** dari **Uber**. Tetapi karena missing value ini berada pada kolom **target** (yang akan dijadikan prediksi), maka seluruh missing value akan dihapus dari dataset karena nantinya akan mengganggu akurasi dari model.

# %%
rides = rides.dropna()

# %%
rides.isna().any()
# Out:
# id                             False
# timestamp                      False
# hour                           False
# day                            False
# month                          False
# datetime                       False
# timezone                       False
# source                         False
# destination                    False
# cab_type                       False
# product_id                     False
# name                           False
# price                          False
# distance                       False
# surge_multiplier               False
# latitude                       False
# longitude                      False
# temperature                    False
# apparentTemperature            False
# short_summary                  False
# long_summary                   False
# precipIntensity                False
# precipProbability              False
# humidity                       False
# windSpeed                      False
# windGust                       False
# windGustTime                   False
# visibility                     False
# temperatureHigh                False
# temperatureHighTime            False
# temperatureLow                 False
# temperatureLowTime             False
# apparentTemperatureHigh        False
# apparentTemperatureHighTime    False
# apparentTemperatureLow         False
# apparentTemperatureLowTime     False
# icon                           False
# dewPoint                       False
# pressure                       False
# windBearing                    False
# cloudCover                     False
# uvIndex                        False
# visibility.1                   False
# ozone                          False
# sunriseTime                    False
# sunsetTime                     False
# moonPhase                      False
# precipIntensityMax             False
# uvIndexTime                    False
# temperatureMin                 False
# temperatureMinTime             False
# temperatureMax                 False
# temperatureMaxTime             False
# apparentTemperatureMin         False
# apparentTemperatureMinTime     False
# apparentTemperatureMax         False
# apparentTemperatureMaxTime     False
# dtype: bool

# %% [markdown]
# Setelah dilakukan lakukan penghapusan missing value pada kolom `price`, sekarang sudah tidak lagi terdapat missing value.

# %% [markdown]
# ### Duplicated Data

# %%
rides.duplicated().sum()
# Out:
# 0

# %%
rides.duplicated().any()
# Out:
# False

# %% [markdown]
# Tidak terdapat duplicated rows pada dataset ini.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# Karena jumlah kolom yang terdapat pada dataset ini sangat banyak, maka pada bagian exploratory daya analysis (**EDA**) akan dilakukan eksplorasi pada kolom-kolom tertentu saja yang saya rasa dapat digunakan sebagai feature.

# %% [markdown]
# ### Price

# %%
plt.figure(figsize=(20,6))
plt.subplot(1, 2, 1)
sns.histplot(x='price', data=rides, bins=50, kde=True)
plt.axvline(rides.price.mean(), color='red', linestyle='dashed', linewidth=2, label='Mean')
plt.axvline(rides.price.median(), color='green', linestyle='dashed', linewidth=2, label='Median')
plt.title('Price Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.legend()
plt.subplot(1, 2, 2)
sns.boxplot(x='price', data=rides)
plt.title('Price Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()
print(f'Skewness: {rides.price.skew()}')
print(f'Mean: {rides.price.mean()}')
print(f'Median: {rides.price.median()}')
# Out:
# Skewness: 1.0457470560899258
# Mean: 16.545125490614065
# Median: 13.5

# %% [markdown]
# Kolom `price` ini memiliki distribusi yang **Highly Skewed** karena nilai skewnessnya lebih dari 1 dengan bentuknya distribusi yang **Right-Skewed**. Dari boxplot ini juga dapat dilihat bahwa kolom ini **memiliki beberapa outlier**.

# %% [markdown]
# ### Time (Hour, Day, Month)

# %%
plt.figure(figsize=(25,10))
plt.subplot(2, 3, 1)
sns.countplot(x='hour', data=rides)
plt.title('Number of Rides per Hour')
plt.xlabel('Hour')
plt.ylabel('Frequency')
plt.subplot(2, 3, 2)
sns.countplot(x='day', data=rides)
plt.title('Number of Rides per Day')
plt.xlabel('Day')
plt.ylabel('Frequency')
plt.subplot(2, 3, 3)
sns.countplot(x='month', data=rides)
plt.title('Number of Rides per Month')
plt.xlabel('Month')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Dapat dilihat jumlah perjalanan mulai **menurun pada jam 1 sampai jam 8** hal ini mungkin disebabkan karena banyak orang yang belum memulai aktifitas pada jam-jam tersebut lalu jumlah perjalanan **kembali naik pada jam 9** saat orang sudah banyak memulai aktifitas. Jumlah perjalanan juga sangat **sedikit pada tanggal 9 dan 10** dengan jumlah perjalan **terbanyak ada pada tanggal 27 dan 28**. Jumlah perjalanan terbanyak berada pada bulan Desember.

# %%
plt.figure(figsize=(25,6))
plt.subplot(1, 2, 1)
sns.boxplot(x='hour', y='price', data=rides)
plt.title('Price Distribution per Hour')
plt.xlabel('Hour')
plt.ylabel('Price')
plt.subplot(1, 2, 2)
sns.boxplot(x='day', y='price', data=rides)
plt.title('Price Distribution per Day')
plt.xlabel('Day')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# Dari boxplot ini dapat diketahui bahwa **tidak ada hubungan linear** antara kolom `price` dengan kolom `hour` dan `day`, maka nantinya kolom-kolom tersebut tidak akan digunakan sebagai feature.

# %% [markdown]
# ### Product ID

# %%
rides.product_id.value_counts()
# Out:
# 9a0e7b09-b92b-4c41-9779-2ad22b4d779d    55096
# 6d318bcc-22a3-4af6-bddd-b409bfce1546    55096
# 6f72dfc5-27f1-42e8-84db-ccc7a75f6969    55096
# 6c84fd89-3f11-4782-9b50-97c468b19529    55095
# 55c66225-fbe7-4fd5-9072-eab1ece5e23e    55094
# 997acbb5-e102-41e1-b155-9df7de0a73f2    55091
# lyft_luxsuv                             51235
# lyft                                    51235
# lyft_lux                                51235
# lyft_premier                            51235
# lyft_plus                               51235
# lyft_line                               51233
# Name: product_id, dtype: int64

# %% [markdown]
# Pada kolom `product_id` ada sekitar **6 product id** yang hanya berbentuk unique value dan tidak memiliki nama, seperti **9a0e7b09-b92b-4c41-9779-2ad22b4d779d** atau **6d318bcc-22a3-4af6-bddd-b409bfce1546**.

# %%
rides.groupby(['product_id', 'name']).size()
# Out:
# product_id                            name
# 55c66225-fbe7-4fd5-9072-eab1ece5e23e  UberX           55094
# 6c84fd89-3f11-4782-9b50-97c468b19529  Black           55095
# 6d318bcc-22a3-4af6-bddd-b409bfce1546  Black SUV       55096
# 6f72dfc5-27f1-42e8-84db-ccc7a75f6969  UberXL          55096
# 997acbb5-e102-41e1-b155-9df7de0a73f2  UberPool        55091
# 9a0e7b09-b92b-4c41-9779-2ad22b4d779d  WAV             55096
# lyft                                  Lyft            51235
# lyft_line                             Shared          51233
# lyft_lux                              Lux Black       51235
# lyft_luxsuv                           Lux Black XL    51235
# lyft_plus                             Lyft XL         51235
# lyft_premier                          Lux             51235
# dtype: int64

# %% [markdown]
# Kolom `product_id` ini ternyata dapat direpresentasi oleh kolom `name` (nama produk), maka kolom `product_id` ini nantinya tidak akan gunakanan sebagai feature.

# %% [markdown]
# ### Cab Type & Name

# %%
plt.figure(figsize=(25,6))
plt.subplot(1, 3, 1)
sns.countplot(x='cab_type', data=rides)
plt.title('Number of Rides per Cab Type')
plt.xlabel('Cab Type')
plt.ylabel('Frequency')
plt.subplot(1, 3, 2)
sns.countplot(x='name', data=rides, hue='cab_type')
plt.title('Number of Rides per Product Name')
plt.xlabel('Name')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.legend(loc='upper left')
plt.subplot(1, 3, 3)
sns.boxplot(x='name', y='price', data=rides, hue='cab_type')
plt.title('Price Distribution per Product Name')
plt.xlabel('Name')
plt.ylabel('Price')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Dari plot diatas dapat dilihat bahwa produk-produk **Uber** lebih banyak melakukan perjalanan ketimbang produk-produk **Lyft**. Nama produk yang digunakanan penumpang ini juga mempengaruhi tarif dari perjalanan seperti **Lux Black XL** merupakan produk paling mahal dari **Lyft** dan **Black SUV** merupakan produk paling mahal dari **Uber**.

# %% [markdown]
# ### Distance

# %%
plt.figure(figsize=(20,6))
plt.subplot(1, 2, 1)
sns.histplot(x='distance', data=rides, bins=50, kde=True)
plt.axvline(rides.distance.mean(), color='red', linestyle='dashed', linewidth=2, label='Mean')
plt.axvline(rides.distance.median(), color='green', linestyle='dashed', linewidth=2, label='Median')
plt.title('Distance Distribution')
plt.xlabel('Distance')
plt.ylabel('Frequency')
plt.legend()
plt.subplot(1, 2, 2)
sns.scatterplot(x='distance', y='price', data=rides, hue='cab_type')
plt.title('Distance vs Price')
plt.xlabel('Distance')
plt.ylabel('Price')
plt.show()
print(f'Skewness: {rides.distance.skew()}')
print(f'Mean: {rides.distance.mean()}')
print(f'Median: {rides.distance.median()}')
# Out:
# Skewness: 0.8168484903389348
# Mean: 2.189261100731062
# Median: 2.16

# %% [markdown]
# Distribusi dari kolom `distance` ini jika dilihat dari nilai skewness dan bentuk dari histogramnya tergolong distribusi **Right-Skewed** walaupun mean dan mediannya berdekatan hal ini mungkin terjadi karena terdapat outlier pada kolom ini. Dari scatter plot juga dapat dilihat bahwa kolom `distance` dan kolom `price` ini memiliki **Positive Correlation** dimana semakin jauh `distance` maka `price` akan semakin besar.
#
# Dari scatter plot juga dapat diketahui bahwa tarif yang ditawarkan oleh **Uber** ini lebih murah dibandingkan **Lyft**.

# %% [markdown]
# ### Surge Multiplier

# %%
rides.groupby(['cab_type', 'surge_multiplier']).size()
# Out:
# cab_type  surge_multiplier
# Lyft      1.00                286433
#           1.25                 11085
#           1.50                  5065
#           1.75                  2420
#           2.00                  2239
#           2.50                   154
#           3.00                    12
# Uber      1.00                330568
# dtype: int64

# %% [markdown]
# Surge multiplier akan meningkat saat banyak permintaan perjalanan yang menyebabkan meningkatnya tarif, pada dataset **Lyft** memasang surge multiplier yang bervariasi mulai dari 1x hingga 3x sedangkan **Uber** tidak ada surge multiplier.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='surge_multiplier', y='price', data=rides, hue='cab_type')
plt.title('Price Distribution per Surge Multiplier')
plt.xlabel('Surge Multiplier')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# Dari boxplot ini dapat dilihat bahwa dengan menikatnya `surge_multiplier` maka `price` pun ikut menigkat, ini menunjukan adanya hubungan antara kolom-kolom tersebut.

# %% [markdown]
# ### Temperature

# %%
plt.figure(figsize=(20, 6))
plt.subplot(1, 2, 1)
sns.histplot(x='temperature', data=rides, bins=50, kde=True)
plt.axvline(rides.temperature.mean(), color='red', linestyle='dashed', linewidth=2, label='Mean')
plt.axvline(rides.temperature.median(), color='green', linestyle='dashed', linewidth=2, label='Median')
plt.title('Temperature Distribution')
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.legend()
plt.subplot(1, 2, 2)
sns.scatterplot(x='temperature', y='price', data=rides, hue='cab_type')
plt.title('Temperature vs Price')
plt.xlabel('Temperature')
plt.ylabel('Price')
plt.show()
print(f'Skewness: {rides.temperature.skew()}')
print(f'Mean: {rides.temperature.mean()}')
print(f'Median: {rides.temperature.median()}')
# Out:
# Skewness: -0.6091907964028547
# Mean: 39.58240610932073
# Median: 40.49

# %% [markdown]
# Distribusi dari `temperature` ini cenderung memiliki distribusi yang **Normal** walaupun jika dilihat dari nilai skewnessnya sedikit Left-Skewed dengan rata-ratanya sekitar 39.58°F ini mungkin karena dataset yang digunakan hanya mendata perjalanan pada bulan november hingga desember di USA yang mana disana sedang musim dingin.
#
# Namun, dari scatter plot tidak menunjukan bahwa adanya hubungan antara `temperature` dengan `price`.

# %% [markdown]
# ### Short Summary (Weather)

# %%
plt.figure(figsize=(20, 6))
plt.subplot(1, 2, 1)
weather = sns.countplot(x='short_summary', data=rides, order=rides.short_summary.value_counts().index)
for p in weather.patches:
    weather.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')
plt.title('Number of Rides per Weather')
plt.xlabel('Weather')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.subplot(1, 2, 2)
sns.boxplot(x='short_summary', y='price', data=rides, hue='cab_type', order=rides.short_summary.value_counts().index)
plt.title('Price Distribution per Weather')
plt.xlabel('Weather')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Karena di USA sedang musim dingin, maka pada kolom `short_summary` atau cuaca ini banyak mentatat saat cuaca **mendung**. Namun, sepertinya cuaca juga tidak mempengaruhi `price` dari sebuah perjalanan jika dilihat dari box plot.

# %% [markdown]
# ### Correlation Between Numeric Columns

# %%
corr = rides.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T


# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Data Inference

# %% [markdown]
# Pada bagian data inference ini akan mengambil sample sebanyak **10 data** dari dataframe utama.

# %%
# Get Data Inference
inference = rides.sample(10, random_state=23)

# Remove Data Inference from main dataframe
rides = rides.drop(inference.index)

inference
# Out:
#                                           id     timestamp  hour  day  month  \
# 348482  b154e87c-e232-4428-8c13-83114eb2cc99  1.543752e+09    12    2     12
# 553944  e40479cb-a317-41e3-942c-0d1e86c3fd70  1.543797e+09     0    3     12
# 111737  bc40f0b7-6ec2-4bd5-bc46-d6764c2009ab  1.543293e+09     4   27     11
# 499239  ede6bafe-fc37-43f4-825e-b1d37dd73e12  1.543265e+09    20   26     11
# 79406   924b4d1a-b75c-4d5b-b6f1-6ccfde593d01  1.543345e+09    18   27     11
# 545059  66fe821e-a6f4-4f76-9e13-ec9976d74715  1.543761e+09    14    2     12
# 44200   cd8f780b-0eb9-4756-8fc6-96d5540d2c7b  1.544935e+09     4   16     12
# 614523  92f3057e-3124-43bc-a94f-766726e675ac  1.543248e+09    15   26     11
# 149512  78ed2549-2db8-4755-8149-40f39c69f433  1.543350e+09    20   27     11
# 334409  6203c75a-308f-49b3-b8db-a4c3d860fff1  1.543360e+09    23   27     11
#
#                    datetime          timezone              source  \
# 348482  2018-12-02 12:08:02  America/New_York  Financial District
# 553944  2018-12-03 00:22:59  America/New_York   Boston University
# 111737  2018-11-27 04:30:22  America/New_York         Beacon Hill
# 499239  2018-11-26 20:38:10  America/New_York    Haymarket Square
# 79406   2018-11-27 18:57:22  America/New_York   Boston University
# 545059  2018-12-02 14:33:03  America/New_York  Financial District
# 44200   2018-12-16 04:40:09  America/New_York    Haymarket Square
# 614523  2018-11-26 15:56:09  America/New_York   Boston University
# 149512  2018-11-27 20:18:22  America/New_York  Financial District
# 334409  2018-11-27 23:00:22  America/New_York       South Station
#
#                     destination cab_type  \
# 348482            South Station     Uber
# 553944            North Station     Lyft
# 111737                North End     Uber
# 499239       Financial District     Lyft
# 79406               Beacon Hill     Lyft
# 545059  Northeastern University     Uber
# 44200             North Station     Uber
# 614523       Financial District     Lyft
# 149512                North End     Lyft
# 334409       Financial District     Lyft
#
#                                   product_id       name  price  distance  \
# 348482  6d318bcc-22a3-4af6-bddd-b409bfce1546  Black SUV   27.5      0.39
# 553944                             lyft_line     Shared   22.5      3.44
# 111737  6f72dfc5-27f1-42e8-84db-ccc7a75f6969     UberXL   14.0      1.35
# 499239                             lyft_line     Shared    5.0      0.89
# 79406                              lyft_line     Shared    7.0      2.73
# 545059  997acbb5-e102-41e1-b155-9df7de0a73f2   UberPool   10.0      2.87
# 44200   9a0e7b09-b92b-4c41-9779-2ad22b4d779d        WAV    7.5      0.49
# 614523                             lyft_plus    Lyft XL   22.5      4.38
# 149512                          lyft_premier        Lux   10.5      1.03
# 334409                             lyft_plus    Lyft XL    9.0      0.63
#
#         surge_multiplier  latitude  longitude  temperature  \
# 348482               1.0   42.3503   -71.0810        41.19
# 553944               1.0   42.3647   -71.0542        48.45
# 111737               1.0   42.3519   -71.0643        43.38
# 499239               1.0   42.3588   -71.0707        44.95
# 79406                1.0   42.3398   -71.0892        41.82
# 545059               1.0   42.3588   -71.0707        43.51
# 44200                1.0   42.3505   -71.1054        40.70
# 614523               1.0   42.3588   -71.0707        44.15
# 149512               1.0   42.3647   -71.0542        43.02
# 334409               1.0   42.3505   -71.1054        40.38
#
#         apparentTemperature    short_summary  \
# 348482                36.49      Light Rain
# 553944                48.45        Overcast
# 111737                37.06            Rain
# 499239                40.72        Overcast
# 79406                 36.10        Overcast
# 545059                39.58      Light Rain
# 44200                 37.51           Clear
# 614523                42.54         Drizzle
# 149512                37.56   Mostly Cloudy
# 334409                35.18   Partly Cloudy
#
#                                              long_summary  precipIntensity  \
# 348482                         Light rain until evening.            0.0923
# 553944                         Light rain until evening.            0.0000
# 111737   Rain until morning, starting again in the eve...           0.1267
# 499239   Rain until morning, starting again in the eve...           0.0021
# 79406                         Light rain in the morning.            0.0000
# 545059                         Light rain until evening.            0.0832
# 44200                  Mostly cloudy throughout the day.            0.0000
# 614523   Rain until morning, starting again in the eve...           0.0074
# 149512                        Light rain in the morning.            0.0000
# 334409                        Light rain in the morning.            0.0000
#
#         precipProbability  humidity  windSpeed  windGust  windGustTime  \
# 348482               1.00      0.92       7.16      7.16    1543755600
# 553944               0.00      0.95       2.74      3.14    1543755600
# 111737               1.00      0.89      12.12     16.82    1543287600
# 499239               0.11      0.86       7.78      7.78    1543287600
# 79406                0.00      0.73       9.51     15.95    1543338000
# 545059               1.00      0.96       6.60      8.47    1543755600
# 44200                0.00      0.69       4.72      5.90    1544918400
# 614523               0.86      0.93       3.53      3.90    1543287600
# 149512               0.00      0.69       9.55     11.74    1543338000
# 334409               0.00      0.71       7.73     11.57    1543305600
#
#         visibility  temperatureHigh  temperatureHighTime  temperatureLow  \
# 348482       4.661            50.80           1543788000           44.97
# 553944       6.639            50.99           1543788000           45.04
# 111737       4.273            46.59           1543255200           41.77
# 499239       8.677            46.27           1543255200           42.20
# 79406        9.991            46.35           1543320000           33.59
# 545059       2.644            50.73           1543788000           44.99
# 44200       10.000            54.29           1544896800           38.48
# 614523       8.561            46.27           1543255200           42.20
# 149512      10.000            47.11           1543320000           33.85
# 334409      10.000            46.74           1543320000           33.82
#
#         temperatureLowTime  apparentTemperatureHigh  \
# 348482          1543816800                    50.13
# 553944          1543816800                    50.32
# 111737          1543298400                    43.97
# 499239          1543298400                    43.78
# 79406           1543399200                    43.38
# 545059          1543816800                    50.06
# 44200           1544954400                    53.62
# 614523          1543298400                    43.78
# 149512          1543399200                    44.14
# 334409          1543399200                    43.93
#
#         apparentTemperatureHighTime  apparentTemperatureLow  \
# 348482                   1543788000                   45.62
# 553944                   1543788000                   45.69
# 111737                   1543251600                   36.47
# 499239                   1543244400                   37.09
# 79406                    1543320000                   29.98
# 545059                   1543788000                   45.64
# 44200                    1544896800                   34.85
# 614523                   1543244400                   37.09
# 149512                   1543320000                   30.03
# 334409                   1543320000                   30.36
#
#         apparentTemperatureLowTime                   icon  dewPoint  pressure  \
# 348482                  1543816800                  rain      39.06   1017.35
# 553944                  1543816800                cloudy      47.14   1002.76
# 111737                  1543298400                  rain      40.38   1000.86
# 499239                  1543298400                cloudy      41.07   1009.25
# 79406                   1543399200                cloudy      33.78    990.20
# 545059                  1543816800                  rain      42.47   1015.25
# 44200                   1544954400           clear-night      31.36   1024.50
# 614523                  1543298400                  rain      42.14   1014.19
# 149512                  1543399200     partly-cloudy-day      33.71    991.00
# 334409                  1543399200   partly-cloudy-night      31.61    991.84
#
#         windBearing  cloudCover  uvIndex  visibility.1  ozone  sunriseTime  \
# 348482          109        1.00        0         4.661  273.9   1543751798
# 553944          286        1.00        0         6.639  287.9   1543751794
# 111737           78        1.00        0         4.273  289.5   1543233000
# 499239          102        1.00        0         8.677  294.1   1543233003
# 79406           261        0.92        1         9.991  316.3   1543319472
# 545059          117        1.00        1         2.644  276.0   1543751797
# 44200            40        0.00        0        10.000  296.0   1544875688
# 614523          117        1.00        1         8.561  295.0   1543233003
# 149512          256        0.82        0        10.000  311.4   1543319468
# 334409          252        0.13        0        10.000  308.4   1543319478
#
#         sunsetTime  moonPhase  precipIntensityMax  uvIndexTime  \
# 348482  1543785242       0.86              0.0916   1543770000
# 553944  1543785233       0.86              0.0888   1543770000
# 111737  1543266976       0.64              0.1227   1543251600
# 499239  1543266976       0.64              0.1234   1543251600
# 79406   1543353356       0.68              0.1419   1543338000
# 545059  1543785238       0.86              0.0904   1543770000
# 44200   1544908439       0.27              0.0082   1544893200
# 614523  1543266976       0.64              0.1234   1543251600
# 149512  1543353343       0.68              0.1430   1543338000
# 334409  1543353358       0.68              0.1438   1543338000
#
#         temperatureMin  temperatureMinTime  temperatureMax  \
# 348482           36.32          1543726800           50.80
# 553944           36.60          1543726800           50.99
# 111737           40.35          1543233600           46.59
# 499239           40.74          1543233600           46.27
# 79406            35.76          1543377600           46.35
# 545059           36.45          1543726800           50.73
# 44200            39.74          1544929200           54.29
# 614523           40.74          1543233600           46.27
# 149512           36.34          1543377600           47.11
# 334409           36.37          1543377600           46.74
#
#         temperatureMaxTime  apparentTemperatureMin  \
# 348482          1543788000                   35.84
# 553944          1543788000                   35.85
# 111737          1543255200                   36.96
# 499239          1543255200                   37.46
# 79406           1543320000                   31.80
# 545059          1543788000                   35.85
# 44200           1544896800                   37.04
# 614523          1543255200                   37.46
# 149512          1543320000                   32.26
# 334409          1543320000                   32.60
#
#         apparentTemperatureMinTime  apparentTemperatureMax  \
# 348482                  1543748400                   50.13
# 553944                  1543748400                   50.32
# 111737                  1543291200                   43.97
# 499239                  1543291200                   43.78
# 79406                   1543377600                   43.38
# 545059                  1543748400                   50.06
# 44200                   1544929200                   53.62
# 614523                  1543291200                   43.78
# 149512                  1543377600                   44.14
# 334409                  1543377600                   43.93
#
#         apparentTemperatureMaxTime
# 348482                  1543788000
# 553944                  1543788000
# 111737                  1543251600
# 499239                  1543244400
# 79406                   1543320000
# 545059                  1543788000
# 44200                   1544896800
# 614523                  1543244400
# 149512                  1543320000
# 334409                  1543320000

# %% [markdown]
# Tabel diatas adalah data inference yang nantinya di uji pada model yang sudah dilatih dan divalidasi.

# %% [markdown]
# ### Split Data

# %% [markdown]
# Membuat dataframe `df_train` dan `df_test` yang akan digunakan untuk melatih dan memvalidasi model.

# %%
df_train, df_test = train_test_split(rides, test_size=0.2, random_state=23)

# %% [markdown]
# Isi dari training dataframe.

# %%
df_train
# Out:
#                                           id     timestamp  hour  day  month  \
# 268495  ef540980-300b-4769-afc1-93a26bac5471  1.543500e+09    14   29     11
# 182164  a99d7c38-a74a-4d94-8ae8-d7d0c507961e  1.545127e+09     9   18     12
# 599312  2dc7e6f1-0868-4739-b3d4-20e585e4b7ca  1.543419e+09    15   28     11
# 343272  3a8609db-3a18-48d6-8138-99fd2f2862d7  1.543701e+09    21    1     12
# 355316  c38da14f-8f43-40b0-9e8d-92f3b8e8696a  1.543420e+09    15   28     11
# ...                                      ...           ...   ...  ...    ...
# 506121  56752611-2141-4a53-b017-5f0590dc154c  1.543793e+09    23    2     12
# 685987  3833780c-8adf-4582-8a91-6988a7c41bc1  1.545114e+09     6   18     12
# 89298   26ce295f-dd03-42aa-8dfb-812e47a5dcb1  1.543454e+09     1   29     11
# 457556  c712a67e-1b8f-4d4f-ad4d-004294d98e50  1.545033e+09     7   17     12
# 368024  ea5ab0cb-16fd-454d-899e-98c37b554c08  1.543891e+09     2    4     12
#
#                    datetime          timezone                   source  \
# 268495  2018-11-29 14:07:56  America/New_York                 West End
# 182164  2018-12-18 09:50:10  America/New_York                   Fenway
# 599312  2018-11-28 15:23:07  America/New_York  Northeastern University
# 343272  2018-12-01 21:52:57  America/New_York                 Back Bay
# 355316  2018-11-28 15:41:25  America/New_York  Northeastern University
# ...                     ...               ...                      ...
# 506121  2018-12-02 23:22:59  America/New_York                   Fenway
# 685987  2018-12-18 06:15:07  America/New_York                North End
# 89298   2018-11-29 01:11:07  America/New_York                   Fenway
# 457556  2018-12-17 07:55:04  America/New_York            South Station
# 368024  2018-12-04 02:33:00  America/New_York                 Back Bay
#
#                destination cab_type                            product_id  \
# 268495           North End     Uber  6f72dfc5-27f1-42e8-84db-ccc7a75f6969
# 182164            Back Bay     Uber  9a0e7b09-b92b-4c41-9779-2ad22b4d779d
# 599312       North Station     Lyft                             lyft_plus
# 343272   Boston University     Lyft                           lyft_luxsuv
# 355316    Theatre District     Uber  6f72dfc5-27f1-42e8-84db-ccc7a75f6969
# ...                    ...      ...                                   ...
# 506121    Theatre District     Uber  55c66225-fbe7-4fd5-9072-eab1ece5e23e
# 685987            Back Bay     Lyft                              lyft_lux
# 89298        North Station     Uber  6c84fd89-3f11-4782-9b50-97c468b19529
# 457556  Financial District     Lyft                              lyft_lux
# 368024              Fenway     Lyft                          lyft_premier
#
#                 name  price  distance  surge_multiplier  latitude  longitude  \
# 268495        UberXL   10.5      0.98               1.0   42.3505   -71.1054
# 182164           WAV    8.0      1.82               1.0   42.3429   -71.1003
# 599312       Lyft XL   19.5      3.31               1.0   42.3519   -71.0551
# 343272  Lux Black XL   38.0      1.47               1.5   42.2148   -71.0330
# 355316        UberXL   16.0      1.89               1.0   42.3519   -71.0551
# ...              ...    ...       ...               ...       ...        ...
# 506121         UberX   10.5      2.66               1.0   42.3588   -71.0707
# 685987     Lux Black   27.5      2.52               1.0   42.3503   -71.0810
# 89298          Black   28.0      3.07               1.0   42.3647   -71.0542
# 457556     Lux Black   16.5      0.57               1.0   42.3519   -71.0643
# 368024           Lux   13.5      1.44               1.0   42.2148   -71.0330
#
#         temperature  apparentTemperature    short_summary  \
# 268495        41.39                36.08   Partly Cloudy
# 182164        26.21                14.47        Overcast
# 599312        41.24                35.90   Mostly Cloudy
# 343272        40.20                38.55   Mostly Cloudy
# 355316        41.24                35.90   Mostly Cloudy
# ...             ...                  ...              ...
# 506121        48.83                48.83        Overcast
# 685987        33.71                25.35        Overcast
# 89298         38.42                32.45   Mostly Cloudy
# 457556        38.41                31.98         Drizzle
# 368024        45.12                40.99   Partly Cloudy
#
#                                       long_summary  precipIntensity  \
# 268495          Partly cloudy throughout the day.            0.0000
# 182164          Mostly cloudy throughout the day.            0.0000
# 599312          Mostly cloudy throughout the day.            0.0000
# 343272   Light rain in the morning and overnight.            0.0000
# 355316          Mostly cloudy throughout the day.            0.0000
# ...                                            ...              ...
# 506121                  Light rain until evening.            0.0000
# 685987          Mostly cloudy throughout the day.            0.0017
# 89298           Mostly cloudy throughout the day.            0.0000
# 457556                 Light rain in the morning.            0.0089
# 368024                      Foggy in the morning.            0.0000
#
#         precipProbability  humidity  windSpeed  windGust  windGustTime  \
# 268495               0.00      0.58       8.41     15.95    1543514400
# 182164               0.00      0.51      14.30     27.25    1545127200
# 599312               0.00      0.60       8.39     12.38    1543431600
# 343272               0.00      0.65       3.03      3.03    1543672800
# 355316               0.00      0.60       8.39     12.38    1543431600
# ...                   ...       ...        ...       ...           ...
# 506121               0.00      0.96       2.83      2.98    1543755600
# 685987               0.11      0.65      11.05     20.20    1545127200
# 89298                0.00      0.72       8.41     11.54    1543431600
# 457556               0.85      0.91       9.33     11.58    1545022800
# 368024               0.00      0.63       7.64      9.95    1543860000
#
#         visibility  temperatureHigh  temperatureHighTime  temperatureLow  \
# 268495       9.994            44.96           1543510800           28.42
# 182164       9.393            32.84           1545159600           20.72
# 599312      10.000            42.60           1543438800           37.33
# 343272       9.454            44.11           1543690800           34.58
# 355316      10.000            42.60           1543438800           37.33
# ...            ...              ...                  ...             ...
# 506121       7.790            50.73           1543788000           44.99
# 685987       5.860            32.75           1545159600           20.66
# 89298        9.915            42.61           1543438800           37.60
# 457556       3.183            41.42           1545076800           23.89
# 368024       9.945            57.87           1543852800           32.80
#
#         temperatureLowTime  apparentTemperatureHigh  \
# 268495          1543579200                    38.85
# 182164          1545220800                    22.96
# 599312          1543489200                    36.56
# 343272          1543712400                    43.44
# 355316          1543489200                    36.56
# ...                    ...                      ...
# 506121          1543816800                    50.06
# 685987          1545220800                    22.75
# 89298           1543489200                    36.57
# 457556          1545138000                    35.95
# 368024          1543921200                    57.20
#
#         apparentTemperatureHighTime  apparentTemperatureLow  \
# 268495                   1543510800                   29.07
# 182164                   1545159600                   14.48
# 599312                   1543435200                   31.82
# 343272                   1543690800                   35.23
# 355316                   1543435200                   31.82
# ...                             ...                     ...
# 506121                   1543788000                   45.64
# 685987                   1545159600                   14.53
# 89298                    1543438800                   32.12
# 457556                   1545076800                   11.83
# 368024                   1543852800                   27.22
#
#         apparentTemperatureLowTime                   icon  dewPoint  pressure  \
# 268495                  1543579200     partly-cloudy-day      27.59   1006.23
# 182164                  1545195600                cloudy      10.70   1005.11
# 599312                  1543478400     partly-cloudy-day      28.42    991.46
# 343272                  1543712400   partly-cloudy-night      29.53   1023.13
# 355316                  1543478400     partly-cloudy-day      28.42    991.46
# ...                            ...                    ...       ...       ...
# 506121                  1543816800                cloudy      47.81   1002.81
# 685987                  1545199200                cloudy      23.09   1001.28
# 89298                   1543478400   partly-cloudy-night      30.30    996.92
# 457556                  1545134400                  rain      36.14   1005.18
# 368024                  1543914000   partly-cloudy-night      33.14   1002.57
#
#         windBearing  cloudCover  uvIndex  visibility.1  ozone  sunriseTime  \
# 268495          314        0.22        1         9.994  331.8   1543492412
# 182164          310        0.95        0         9.393  365.4   1545135001
# 599312          297        0.74        1        10.000  351.9   1543405934
# 343272           99        0.54        0         9.454  271.9   1543665299
# 355316          297        0.74        1        10.000  351.9   1543405934
# ...             ...         ...      ...           ...    ...          ...
# 506121          275        1.00        0         7.790  287.3   1543751797
# 685987          314        1.00        0         5.860  362.1   1545134998
# 89298           297        0.77        0         9.915  349.9   1543405936
# 457556           23        1.00        0         3.183  331.1   1545048558
# 368024          271        0.48        0         9.945  329.7   1543838223
#
#         sunsetTime  moonPhase  precipIntensityMax  uvIndexTime  \
# 268495  1543526107       0.75              0.0000   1543510800
# 182164  1545167693       0.37              0.0056   1545152400
# 599312  1543439719       0.72              0.0000   1543420800
# 343272  1543698873       0.82              0.0000   1543683600
# 355316  1543439719       0.72              0.0000   1543420800
# ...            ...        ...                 ...          ...
# 506121  1543785238       0.86              0.0904   1543770000
# 685987  1545167687       0.37              0.0028   1545152400
# 89298   1543439716       0.72              0.0000   1543420800
# 457556  1545081262       0.33              0.0178   1545066000
# 368024  1543871641       0.89              0.0007   1543852800
#
#         temperatureMin  temperatureMinTime  temperatureMax  \
# 268495           35.20          1543550400           44.96
# 182164           22.98          1545192000           37.95
# 599312           33.70          1543399200           42.60
# 343272           30.17          1543662000           44.11
# 355316           33.70          1543399200           42.60
# ...                ...                 ...             ...
# 506121           36.45          1543726800           50.73
# 685987           23.23          1545192000           38.10
# 89298            33.85          1543399200           42.61
# 457556           34.07          1545044400           41.42
# 368024           42.96          1543896000           57.87
#
#         temperatureMaxTime  apparentTemperatureMin  \
# 268495          1543510800                   31.40
# 182164          1545109200                   12.13
# 599312          1543438800                   29.88
# 343272          1543690800                   25.87
# 355316          1543438800                   29.88
# ...                    ...                     ...
# 506121          1543788000                   35.85
# 685987          1545109200                   12.12
# 89298           1543438800                   30.03
# 457556          1545076800                   28.11
# 368024          1543852800                   39.41
#
#         apparentTemperatureMinTime  apparentTemperatureMax  \
# 268495                  1543550400                   38.85
# 182164                  1545134400                   32.03
# 599312                  1543399200                   36.56
# 343272                  1543662000                   43.44
# 355316                  1543399200                   36.56
# ...                            ...                     ...
# 506121                  1543748400                   50.06
# 685987                  1545134400                   32.10
# 89298                   1543399200                   36.57
# 457556                  1545044400                   35.95
# 368024                  1543896000                   57.20
#
#         apparentTemperatureMaxTime
# 268495                  1543510800
# 182164                  1545109200
# 599312                  1543435200
# 343272                  1543690800
# 355316                  1543435200
# ...                            ...
# 506121                  1543788000
# 685987                  1545109200
# 89298                   1543438800
# 457556                  1545076800
# 368024                  1543852800
#
# [510372 rows x 57 columns]

# %% [markdown]
# `df_train` ini memiliki **510372 baris** dengan **57 kolom**.

# %% [markdown]
# Isi dari validation dataframe.

# %%
df_test
# Out:
#                                           id     timestamp  hour  day  month  \
# 565768  9ae0e6ab-3bbe-45c2-b970-f8b569ae2c47  1.544716e+09    15   13     12
# 630762  6053bb06-fd1f-4b4f-b89c-12c80f3b529d  1.544703e+09    12   13     12
# 551956  903c051b-df8b-49f4-a180-c2a528e7e882  1.545057e+09    14   17     12
# 560206  3641b982-deef-494f-8dcb-c0324e5c3390  1.544983e+09    18   16     12
# 504669  aa2280d9-fb63-48a5-ac6c-c3cebf911716  1.545081e+09    21   17     12
# ...                                      ...           ...   ...  ...    ...
# 501752  7b8a400f-01c9-4524-adfb-59ca719b8c3b  1.543585e+09    13   30     11
# 238566  cdd73d55-8a25-4ec6-941e-0b2600f4976f  1.543265e+09    20   26     11
# 395706  c74c1680-7988-46ec-ae71-e59b2033cd39  1.544730e+09    19   13     12
# 128867  e881ab13-043c-4a10-bc28-eb6a8c302cf9  1.545125e+09     9   18     12
# 347249  676ed3ea-0207-4ee2-89c6-d8b5110de90a  1.543465e+09     4   29     11
#
#                    datetime          timezone              source  \
# 565768  2018-12-13 15:40:07  America/New_York  Financial District
# 630762  2018-12-13 12:15:05  America/New_York       South Station
# 551956  2018-12-17 14:30:12  America/New_York  Financial District
# 560206  2018-12-16 18:00:08  America/New_York           North End
# 504669  2018-12-17 21:15:09  America/New_York              Fenway
# ...                     ...               ...                 ...
# 501752  2018-11-30 13:32:57  America/New_York    Haymarket Square
# 238566  2018-11-26 20:38:09  America/New_York       South Station
# 395706  2018-12-13 19:45:13  America/New_York            West End
# 128867  2018-12-18 09:30:05  America/New_York  Financial District
# 347249  2018-11-29 04:19:21  America/New_York         Beacon Hill
#
#                     destination cab_type  \
# 565768  Northeastern University     Lyft
# 630762              Beacon Hill     Uber
# 551956                North End     Uber
# 560206                 Back Bay     Uber
# 504669       Financial District     Uber
# ...                         ...      ...
# 501752                 West End     Lyft
# 238566              Beacon Hill     Uber
# 395706            South Station     Uber
# 128867                   Fenway     Uber
# 347249            South Station     Uber
#
#                                   product_id       name  price  distance  \
# 565768                                  lyft       Lyft   10.5      3.37
# 630762  6c84fd89-3f11-4782-9b50-97c468b19529      Black   22.0      2.58
# 551956  6c84fd89-3f11-4782-9b50-97c468b19529      Black   16.0      1.21
# 560206  6f72dfc5-27f1-42e8-84db-ccc7a75f6969     UberXL   16.5      2.34
# 504669  6f72dfc5-27f1-42e8-84db-ccc7a75f6969     UberXL   24.0      4.40
# ...                                      ...        ...    ...       ...
# 501752                          lyft_premier        Lux   10.5      0.69
# 238566  6d318bcc-22a3-4af6-bddd-b409bfce1546  Black SUV   30.5      2.50
# 395706  55c66225-fbe7-4fd5-9072-eab1ece5e23e      UberX    9.5      2.14
# 128867  6d318bcc-22a3-4af6-bddd-b409bfce1546  Black SUV   44.0      4.50
# 347249  6c84fd89-3f11-4782-9b50-97c468b19529      Black   20.5      2.48
#
#         surge_multiplier  latitude  longitude  temperature  \
# 565768               1.0   42.3519   -71.0643        28.42
# 630762               1.0   42.3505   -71.1054        20.01
# 551956               1.0   42.3644   -71.0661        36.45
# 560206               1.0   42.3588   -71.0707        42.82
# 504669               1.0   42.3505   -71.1054        40.47
# ...                  ...       ...        ...          ...
# 501752               1.0   42.3647   -71.0542        31.80
# 238566               1.0   42.3588   -71.0707        44.95
# 395706               1.0   42.3647   -71.0542        32.85
# 128867               1.0   42.3429   -71.1003        26.21
# 347249               1.0   42.3519   -71.0551        38.18
#
#         apparentTemperature    short_summary  \
# 565768                28.42   Partly Cloudy
# 630762                15.11   Partly Cloudy
# 551956                31.00        Overcast
# 560206                38.16        Overcast
# 504669                35.92   Mostly Cloudy
# ...                     ...              ...
# 501752                31.80           Clear
# 238566                40.72        Overcast
# 395706                32.85   Mostly Cloudy
# 128867                14.47        Overcast
# 347249                32.09   Mostly Cloudy
#
#                                              long_summary  precipIntensity  \
# 565768                 Partly cloudy throughout the day.            0.0000
# 630762                 Partly cloudy throughout the day.            0.0000
# 551956                        Light rain in the morning.            0.0005
# 560206                          Rain throughout the day.            0.0012
# 504669                        Light rain in the morning.            0.0000
# ...                                                   ...              ...
# 501752                 Mostly cloudy throughout the day.            0.0000
# 238566   Rain until morning, starting again in the eve...           0.0021
# 395706                 Partly cloudy throughout the day.            0.0000
# 128867                 Mostly cloudy throughout the day.            0.0000
# 347249                 Mostly cloudy throughout the day.            0.0000
#
#         precipProbability  humidity  windSpeed  windGust  windGustTime  \
# 565768               0.00      0.57       2.81      4.06    1544738400
# 630762               0.00      0.65       3.39      3.39    1544738400
# 551956               0.09      0.88       6.79      8.73    1545022800
# 560206               0.14      0.77       7.72      8.96    1545015600
# 504669               0.00      0.71       6.64      7.91    1545022800
# ...                   ...       ...        ...       ...           ...
# 501752               0.00      0.83       2.10      4.79    1543554000
# 238566               0.11      0.86       7.78      7.78    1543287600
# 395706               0.00      0.56       2.65      3.83    1544738400
# 128867               0.00      0.51      14.30     27.25    1545127200
# 347249               0.00      0.70       8.52      9.67    1543431600
#
#         visibility  temperatureHigh  temperatureHighTime  temperatureLow  \
# 565768       9.725            33.92           1544731200           27.05
# 630762       9.968            33.51           1544731200           26.51
# 551956       9.037            41.39           1545076800           23.87
# 560206      10.000            43.68           1544990400           34.25
# 504669       9.770            41.44           1545076800           24.05
# ...            ...              ...                  ...             ...
# 501752      10.000            42.52           1543600800           31.71
# 238566       8.677            46.27           1543255200           42.20
# 395706       9.959            33.83           1544731200           27.27
# 128867       9.393            32.84           1545159600           20.72
# 347249      10.000            42.60           1543438800           37.33
#
#         temperatureLowTime  apparentTemperatureHigh  \
# 565768          1544781600                    32.95
# 630762          1544788800                    32.84
# 551956          1545138000                    35.93
# 560206          1545044400                    38.28
# 504669          1545134400                    36.09
# ...                    ...                      ...
# 501752          1543658400                    40.53
# 238566          1543298400                    43.78
# 395706          1544781600                    32.85
# 128867          1545220800                    22.96
# 347249          1543489200                    36.56
#
#         apparentTemperatureHighTime  apparentTemperatureLow  \
# 565768                   1544734800                   24.47
# 630762                   1544731200                   27.16
# 551956                   1545076800                   11.81
# 560206                   1544986800                   28.40
# 504669                   1545076800                   12.30
# ...                             ...                     ...
# 501752                   1543611600                   28.06
# 238566                   1543244400                   37.09
# 395706                   1544734800                   24.61
# 128867                   1545159600                   14.48
# 347249                   1543435200                   31.82
#
#         apparentTemperatureLowTime                   icon  dewPoint  pressure  \
# 565768                  1544785200     partly-cloudy-day      15.14   1034.03
# 630762                  1544788800   partly-cloudy-night       9.98   1032.46
# 551956                  1545134400                cloudy      33.32   1003.86
# 560206                  1545044400                cloudy      35.99   1016.38
# 504669                  1545134400   partly-cloudy-night      31.95    999.95
# ...                            ...                    ...       ...       ...
# 501752                  1543658400             clear-day      27.14   1017.01
# 238566                  1543298400                cloudy      41.07   1009.25
# 395706                  1544785200     partly-cloudy-day      18.66   1033.65
# 128867                  1545195600                cloudy      10.70   1005.11
# 347249                  1543478400   partly-cloudy-night      29.13    998.75
#
#         windBearing  cloudCover  uvIndex  visibility.1  ozone  sunriseTime  \
# 565768           13        0.21        1         9.725  326.9   1544702792
# 630762          342        0.41        0         9.968  329.2   1544702801
# 551956          328        1.00        1         9.037  326.0   1545048561
# 560206           71        1.00        1        10.000  323.2   1544962122
# 504669          286        0.76        0         9.770  354.4   1545048567
# ...             ...         ...      ...           ...    ...          ...
# 501752          296        0.01        0        10.000  277.1   1543578867
# 238566          102        1.00        0         8.677  294.1   1543233003
# 395706           76        0.64        0         9.959  330.8   1544702792
# 128867          310        0.95        0         9.393  365.4   1545135001
# 347249          303        0.59        0        10.000  346.7   1543405934
#
#         sunsetTime  moonPhase  precipIntensityMax  uvIndexTime  \
# 565768  1544735604       0.21              0.0001   1544716800
# 630762  1544735614       0.21              0.0001   1544720400
# 551956  1545081260       0.33              0.0185   1545066000
# 560206  1544994844       0.30              0.1250   1544979600
# 504669  1545081273       0.33              0.0217   1545066000
# ...            ...        ...                 ...          ...
# 501752  1543612470       0.79              0.0003   1543593600
# 238566  1543266976       0.64              0.1234   1543251600
# 395706  1544735599       0.21              0.0001   1544716800
# 128867  1545167693       0.37              0.0056   1545152400
# 347249  1543439719       0.72              0.0000   1543420800
#
#         temperatureMin  temperatureMinTime  temperatureMax  \
# 565768           18.05          1544688000           33.92
# 630762           18.11          1544688000           33.51
# 551956           34.07          1545044400           41.39
# 560206           39.01          1544954400           43.68
# 504669           34.22          1545044400           41.44
# ...                ...                 ...             ...
# 501752           28.79          1543579200           42.52
# 238566           40.74          1543233600           46.27
# 395706           18.29          1544688000           33.83
# 128867           22.98          1545192000           37.95
# 347249           33.70          1543399200           42.60
#
#         temperatureMaxTime  apparentTemperatureMin  \
# 565768          1544731200                   13.60
# 630762          1544731200                   14.08
# 551956          1545076800                   28.17
# 560206          1544990400                   34.03
# 504669          1545076800                   28.61
# ...                    ...                     ...
# 501752          1543600800                   26.41
# 238566          1543255200                   37.46
# 395706          1544731200                   13.79
# 128867          1545109200                   12.13
# 347249          1543438800                   29.88
#
#         apparentTemperatureMinTime  apparentTemperatureMax  \
# 565768                  1544688000                   32.95
# 630762                  1544688000                   32.84
# 551956                  1545044400                   35.93
# 560206                  1545019200                   38.28
# 504669                  1545044400                   36.09
# ...                            ...                     ...
# 501752                  1543575600                   40.53
# 238566                  1543291200                   43.78
# 395706                  1544688000                   32.85
# 128867                  1545134400                   32.03
# 347249                  1543399200                   36.56
#
#         apparentTemperatureMaxTime
# 565768                  1544734800
# 630762                  1544731200
# 551956                  1545076800
# 560206                  1544986800
# 504669                  1545076800
# ...                            ...
# 501752                  1543611600
# 238566                  1543244400
# 395706                  1544734800
# 128867                  1545109200
# 347249                  1543435200
#
# [127594 rows x 57 columns]

# %% [markdown]
# `df_test` ini memiliki **127594 baris** dengan **57 kolom**.
